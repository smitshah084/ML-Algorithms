# %%
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
import seaborn as sb
from time import process_time

# %%
def generate_data(ran,m=100,n=1,noise=0.1):
    
    ones = np.ones((m,1))
    np.random.seed(ran)
    X1 = np.random.uniform(low = 125.0 ,high = 400.0 ,size = (m,))
    X2 = np.random.uniform(low = 125.0 ,high = 400.0 ,size = (m,))
    
#     Multivaiate 
#     y = np.array(20*(X1**2) - 13*(X2**2) + 108*(X2) + 12)

#     univariate
    y = X1**3 + 32 
    
    DF = pd.DataFrame({'X1':X1,'X2':X2,'y':y})
    
    plt.scatter(X1,y)
    plt.show()
    plt.close()
    plt.scatter(X2,y)
    plt.show()
    plt.close()
    
    return DF

DF = generate_data(0)

DF.head()
# Out:
#            X1          X2             y
# 0  275.923714  311.399548  2.100718e+07
# 1  321.677076  199.252193  3.328593e+07
# 2  290.759928  327.178356  2.458126e+07
# 3  274.842875  389.601850  2.076128e+07
# 4  241.505070  193.407114  1.408574e+07

# %%
sb.heatmap(DF.corr(),annot=True)
# Out:
# <Axes: >

# %%
def normalise(X):
    
    X = (X - X.mean()) / X.std() 
    
    return X

# %%
def preprocess(X):
#     input,output type: DataFrame 
    
    poly = PolynomialFeatures(2)
    temp = poly.fit_transform(X)
    temp = pd.DataFrame(temp)
    temp.columns = poly.get_feature_names_out(X.columns)
    temp.iloc[:,1:] = normalise(temp.iloc[:,1:])
    vn = len(temp.columns)
    
    return temp ,vn

# %%
def h(X,theta):
#     X:(m,vn) ,theta:(vn,1)
    return X@theta # (vn,1)

# %%
def j(X,y,theta):
    
    temp = (h(X,theta) - y)**2
    c = 1/(2*m)
    temp = np.sum(temp,axis=1)[0]
    
    return c*temp

# %%
def G(X,y,theta,alpha,lambda_):
    
    temp1 = (alpha*lambda_)/m # int
    temp2 = X.transpose() # (vn,m)
    temp3 = h(X,theta) - y # (m,1)
    temp4 = temp2 @ temp3 # (vn,1)
#     print(temp1,temp2.shape,temp3.shape,temp4.shape)
    
    return theta - (temp1 * temp4)

# %%
def GD(X,y,alpha,lambda_,thresh):
    
    cols = X.columns
    X = X.values
    y = y.values.reshape(-1,1)
    
    theta = np.random.rand(vn,1)
    iter_ = 1
    cost_diff = 1
    m = len(X)
    
    init_cost = j(X,y,theta)
    print("initial cost: ",init_cost)
    
    costs = [init_cost]
    
    while cost_diff >= thresh:
#     while iter_ <= 100:
        
        cur_cost = j(X,y,theta)
        theta = G(X,y,theta,alpha,lambda_)
        after_cost = j(X,y,theta)
        costs.append(after_cost)
        
        cost_diff = cur_cost - after_cost
        iter_ += 1
        
    print("Final Cost: ",costs[-1])
    print("Total interations: ",iter_)
    
    plt.plot(costs)
    
    return theta

# %%
X_DF = DF.drop(['y'],axis=1)
y_DF = DF['y']
n = len(X_DF.columns)+1

poly, vn = preprocess(X_DF)
print(vn,n)
poly.head()
# Out:
# 6 3
#      1        X1        X2      X1^2     X1 X2      X2^2
# 0  1.0  0.262359  0.538415  0.116052  0.632930  0.445722
# 1  1.0  0.836556 -0.927979  0.775228 -0.160617 -0.959954
# 2  1.0  0.448551  0.744732  0.318741  0.967682  0.693042
# 3  1.0  0.248795  1.560957  0.101701  1.402087  1.791303
# 4  1.0 -0.169589 -1.004407 -0.313298 -0.792689 -1.016289

# %%
alpha = 1e-3
lambda_ = 1
thresh = 0.01
m = poly.shape[0]

theta = GD(poly,y_DF,alpha,lambda_,thresh)
# Out:
# initial cost:  437235279.64695865
# Final Cost:  16.357480332618703
# Total interations:  2314

# %%
theta
# Out:
# array([[ 388450.16648227],
#        [ 371899.12188402],
#        [-280974.33191043],
#        [ 398319.24800669],
#        [  75434.43441617],
#        [-298254.48420981]])

# %%
test_DF = generate_data(40)

# %%
def predict(X,theta):
    
    poly_test, vn = preprocess(X)
    poly_test = poly_test.values
    
    return h(poly_test,theta)

# %%
X_test = test_DF.drop(['y'],axis=1)
y_test = test_DF['y']
n = len(X_test.columns)+1
y_pred = predict(X_test,theta)
y_pred.shape
# Out:
# (100, 1)

# %%
plt.scatter(X_test['X1'],y_test)
plt.scatter(X_test['X1'],y_pred,c='r')
plt.show()
plt.close()
plt.scatter(X_test['X2'],y_test)
plt.scatter(X_test['X2'],y_pred,c='r')
